# %%
import glob

# %%
# 파일 불러오기
tmp_raw = []

for file_name in glob.glob('./data/data/corona/*.csv'):
    tmp = pd.read_csv(file_name)
    tmp_raw.append(tmp)

# 불러온 파일 합치기
df_raw = pd.concat(tmp_raw)

# %%
df_raw
# Out:
#    2020-01  2020-02  2020-03  2020-04  2020-05  2020-06  2020-07  2020-08  \
# 0       11     3139     6636     3492      703     1334     1506   5642.0
# 0        0        1        9        4       11       11       14     91.0
# 0        0        0        0        0       28       14       12      NaN
# 0        0        1       33        1        6       45        5     60.0
# 0        0        1       11        0        3       17        7     34.0
# 0        0        0        0       25        8       15        6    172.0
# 0        0        0        6        3       10       43        2     73.0
# 0        0        1       25        5        3        4        6     76.0
# 0        0        1       23        7        9       12       18    107.0
# 0        0        1       14        9        3       12       14     82.0
# 0        0        4        8        5        7        7        5     50.0
# 0        0       12       13       13       11        7       43    160.0
# ...
