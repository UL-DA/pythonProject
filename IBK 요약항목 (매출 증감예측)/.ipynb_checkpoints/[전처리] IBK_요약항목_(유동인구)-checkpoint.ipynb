# %%
import psycopg2
import numpy as np
import pandas as pd

# %%
# DB Connect
conn = psycopg2.connect(
    host='redshift-cluster-1.ctvbwnnvbdkl.ap-northeast-2.redshift.amazonaws.com',
    port=5439,
    dbname='dev',
    user='awsuser',
    password='cremaoAdmin1234qwer!!'
)
cursor = conn.cursor()
query = 'select * from m1.kt_bldg_xy_info where base_ym between 202001 and 202012'
df_2020 = cursor.execute(query)
df_2020.to_csv('./m1.kt_bldg_xy_info)2020.csv', index=False, encoding='utf-8-sig')

# %%
df_2020

# %%
df_xy = pd.read_csv('c:/oasis/KT_data/dp_frc_bldg_basexy_m_sum_202205.csv',sep='|')

# %%
df_xy
# Out:
#          base_ym                  bd_mgt_sn  mka_a01  mka_a02  mka_a03  \
# 0         202205  3023011100101840009001556       17        4        5
# 1         202205  4831010500117000022000001      336       57       53
# 2         202205  1121510100106380005005393      196       33       20
# 3         202205  2641010700104150033010027      256       29       35
# 4         202205  1174010800104490018004300      104        9       19
# ...          ...                        ...      ...      ...      ...
# 1366992   202205  4111313700111940006069708      296       49       66
# 1366993   202205  4831010800112010008000001      180       21       14
# 1366994   202205  4119510100100470010002593      236       11       26
# 1366995   202205  1117013100106530025029094      171       17       18
# 1366996   202205  1144010400101840022026022      267       30       50
#
#          mka_a04  mka_a05  mka_a06  mka_a07  mka_a08  ...  w_fri_avg  \
# ...

# %%
df_xy['base_ym'].value_counts()
# Out:
# 202205    1366997
# Name: base_ym, dtype: int64

# %% [markdown]
# ### 1. f_tot : 유동인구

# %%
df_xy['']
